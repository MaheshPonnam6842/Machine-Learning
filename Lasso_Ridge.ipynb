# ..        ...       ...       ...       ...       ...       ...       ...
# 195  0.500333 -0.774601 -0.993825  0.307204  0.044206  0.832110  0.546968
# 196  0.093365 -0.659427  0.004001 -0.714387 -0.780377 -0.336150 -0.119423
# 197  0.059655 -0.163061  0.756115 -0.531876 -0.286706  0.670167 -0.031396
# 198 -0.725518  1.187127 -1.113844  0.226657 -0.128128  1.043043  0.595832
# 199  0.902492  0.952591  0.387827  1.377367  0.378354  1.713530 -1.619920
#
# [200 rows x 150 columns]

# %%
y=df['target']

# %%
y
# Out:
# 0       10.681366
# 1      -60.163343
# 2      131.226545
# 3     -131.889020
# 4     -138.566956
#           ...
# 195    -18.681830
# 196    234.589644
# 197    -94.329646
# 198     80.152034
# 199    110.131842
# Name: target, Length: 200, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
Linear_model=LinearRegression()

# %%
Linear_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
Linear_model.score(X_test,y_test)
# Out:
# 0.7382357071523057

# %%
Lasso_model=Lasso(alpha=1.0)

# %%
Lasso_model.fit(X_train,y_train)
# Out:
# Lasso()

# %%
Lasso_model.score(X_test,y_test)
# Out:
# 0.9901476660336154

# %%
Ridge_model=Ridge(alpha=1.0)

# %%
Ridge_model.fit(X_test,y_test)
# Out:
# Ridge()

# %%
Ridge_model.score(X_test,y_test)
# Out:
# 0.9999139143135097

# %%
Ridge_model.predict(X_test)
# Out:
# array([  40.11102191,  209.14502378,  108.12963495,  196.73356415,
#         -86.40582225,  142.33583069,  -50.27414503, -108.7862073 ,
#        -130.29343793, -174.38697398,  174.34184473,   73.33661912,
#        -107.16919084,  -94.09596505,   23.63496498,  -51.05987161,
#        -129.71977458,  141.47390394,  149.72869639,  -67.94643483,
#         137.45980537,   55.98535129,  -66.02811081,   29.65138038,
#         -61.56564378, -106.73239607,  -56.91855511,    3.82519162,
#         207.65854699,  -75.47533119, -114.88143981, -174.01492373,
#         -20.09796023,   11.87218226,   71.63252621,   30.46403442,
#         111.37550192,  -10.17943597,  -47.85568422,   30.92850994,
#         -16.37419765,  -93.06653894,   13.68301198,  130.19256871,
#        -348.14828798,  -18.60572487,  301.01509334,  129.73280604,
#        -176.97938978,  238.75925892])

# %%
# Out:
# 95      40.722471
# 15     210.064672
# 30     108.833073
# 158    198.377185
# 128    -87.044822
# 115    144.430205
# 69     -52.043950
# 170   -110.561339
# 174   -130.341046
# 45    -176.307227
# 66     175.257112
# 182     73.505074
# 165   -107.835435
# 78     -94.554655
# 186     22.491120
# 177    -51.725656
# 56    -130.600523
# 152    142.534602
# 82     151.287423
# 68     -69.573950
# 124    140.041044
# 16      55.697495
# 148    -66.076529
# 93      28.400494
# 65     -62.436108
# 60    -107.000652
# 84     -56.373950
# 67       4.133193
# 125    208.445573
# 132    -76.681839
# 9     -115.479545
# 18    -175.516244
# 55     -20.193763
# 75      12.701868
# 150     73.486489
# 104     32.380157
# 135    113.090516
# 137    -11.377882
# 164    -47.702714
# 76      31.663733
# 79     -17.334274
# 197    -94.329646
# 38      13.336016
# 24     130.354943
# 122   -350.535447
# 195    -18.681830
# 29     301.973805
# 19     130.524825
# 143   -177.908598
# 86     240.629966
# Name: target, dtype: float64

# %%
Linear_model.coef_[:4],Linear_model.intercept_
# Out:
# (array([ 30.57745869, -35.77372452,  13.35279782,   0.12629716]),
#  -2.891323758684271)

# %%
Lasso_model.coef_[:4],Lasso_model.intercept_
# Out:
# (array([-0.        , -0.24441233, 19.72524353,  0.        ]),
#  0.40750894954108396)
